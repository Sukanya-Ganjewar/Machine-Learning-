# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\SGanjewa\Documents\Python Class Notes\bng_property.csv")

# %%
df.isna().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
missing_values=["n/a","na","--"]

# %%
df=pd.read_csv(r"C:\Users\SGanjewa\Documents\Python Class Notes\bng_property.csv",na_values=missing_values)

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
#Exception Handling
count=0    #Counter
for row in df['OWN_OCCUPIED']: #MEMBERSHIP OPERATOR
    try: 
        int(row)
        df.loc[count, 'OWN_OCCUPIED']=np.nan
    except ValueError:
        pass
    count= count + 1

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['PID'] = df['PID'].interpolate()

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['ST_NUM'] = df['ST_NUM'].interpolate()

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0   199.0   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0   210.0  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['OWN_OCCUPIED'] = df['OWN_OCCUPIED'].fillna('Y')

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0   199.0   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0   210.0  WASHINGTON            Y           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df['NUM_BEDROOMS'] = df['NUM_BEDROOMS'].fillna(df.NUM_BEDROOMS.median())

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0   199.0   LEXINGTON            N           2.5        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           2.5        1   800.0
# 6  100007000.0   210.0  WASHINGTON            Y           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           2.5        2  1800.0

# %%
count=0
for row in df['NUM_BATH']:
    try: 
        float(row) 
        pass
    except ValueError:
        df.loc[count,'NUM_BATH']=np.nan
    count += 1

# %%
df['NUM_BATH'] = df['NUM_BATH'].fillna(df.NUM_BATH.median())

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0   199.0   LEXINGTON            N           2.5        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y           1.0        1   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           2.5        1   800.0
# 6  100007000.0   210.0  WASHINGTON            Y           2.0        1   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           2.5        2  1800.0

# %%
df['SQ_FT']=df['SQ_FT'].interpolate()

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   925.0
# 2  100003000.0   199.0   LEXINGTON            N           2.5        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y           1.0        1   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           2.5        1   800.0
# 6  100007000.0   210.0  WASHINGTON            Y           2.0        1   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1  1375.0
# 8  100009000.0   215.0     TREMONT            Y           2.5        2  1800.0

# %%
df['NUM_BEDROOMS']=df['NUM_BEDROOMS'].astype(int)

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y             3        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N             3      1.5   925.0
# 2  100003000.0   199.0   LEXINGTON            N             2        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y             1        1   700.0
# 4  100005000.0   203.0    BERKELEY            Y             3        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y             2        1   800.0
# 6  100007000.0   210.0  WASHINGTON            Y             2        1   950.0
# 7  100008000.0   213.0     TREMONT            Y             1        1  1375.0
# 8  100009000.0   215.0     TREMONT            Y             2        2  1800.0
